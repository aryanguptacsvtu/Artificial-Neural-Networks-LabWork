# %%
import numpy as np
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense

# %%
df = yf.download("AAPL", period="1y")
data = df[['Close']].values
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_27860\1759194013.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("AAPL", period="1y")
# [*********************100%***********************]  1 of 1 completed

# %%
scaler = MinMaxScaler()
scaled = scaler.fit_transform(data)

# %%
X, y = [], []

for i in range(60, len(scaled)):
    X.append(scaled[i-60:i])
    y.append(scaled[i])
    
X, y = np.array(X), np.array(y)

# %%
model_lstm = Sequential([LSTM(50, return_sequences=False, input_shape=(60,1)), Dense(1)])
model_lstm.compile(optimizer='adam', loss='mse')
model_lstm.fit(X, y, epochs=3, batch_size=16)
# Out:
# c:\Users\gupta\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/3
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.1251
# Epoch 2/3
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0192
# Epoch 3/3
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0137

# %%
model_gru = Sequential([GRU(50, return_sequences=False, input_shape=(60,1)), Dense(1)])
model_gru.compile(optimizer='adam', loss='mse')
model_gru.fit(X, y, epochs=3, batch_size=16)
# Out:
# Epoch 1/3
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.1198
# Epoch 2/3
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0173
# Epoch 3/3
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0114

# %%
print("Training complete.")
# Out:
# Training complete.
