# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# Generate sine wave data
def generate_sine(n=1500):
    x = np.arange(n)
    return np.sin(0.01 * x)

data = generate_sine()

# %%
# Scale data
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data.reshape(-1,1))

# %%
# Create sequences
def create_seq(series, seq_len):
    X, y = [], []

    for i in range(len(series) - seq_len):
        X.append(series[i:i+seq_len])
        y.append(series[i+seq_len])
        
    return np.array(X), np.array(y)

SEQ_LEN = 50
X, y = create_seq(data_scaled, SEQ_LEN)

# %%
# Train-test split
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
# Build LSTM model
model = Sequential([LSTM(64, input_shape=(SEQ_LEN,1)),
                    Dropout(0.2),
                    Dense(1)])
# Out:
# c:\Users\gupta\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=20, batch_size=32, verbose=1)
# Out:
# Epoch 1/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0877
# Epoch 2/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0064
# Epoch 3/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0046
# Epoch 4/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0044
# Epoch 5/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0033
# Epoch 6/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0033
# Epoch 7/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0033
# Epoch 8/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0026
# Epoch 9/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0025
# Epoch 10/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0023
# Epoch 11/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0024
# Epoch 12/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0023
# Epoch 13/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0020
# Epoch 14/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0020
# Epoch 15/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0019
# Epoch 16/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0019
# Epoch 17/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0019
# Epoch 18/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0018
# Epoch 19/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0017
# Epoch 20/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0019

# %%
# Predict
pred = model.predict(X_test)
pred_inv = scaler.inverse_transform(pred)
y_test_inv = scaler.inverse_transform(y_test)
print("Prediction completed.")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# Prediction completed.
